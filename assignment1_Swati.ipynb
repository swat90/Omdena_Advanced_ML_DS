# %% [markdown]
# <a href="https://colab.research.google.com/github/swat90/Omdena_Advanced_ML_DS/blob/main/assignment1_Swati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Foundations of Data Science: Practical Assignment**
# ## **Task 1: Introduction to Data Science**
# Data Science Overview: Provide a brief explanation of what data science is and its significance in various industries.
#
# **Data Science** as the name suggests brings tow disciplines, data and science. Data refers to raw facts, observations, measurements, or records that are collected, stored, and processed. Data can take various forms, such as numbers, text, images, or any other structured or unstructured information.
#
# Data science is a multidisciplinary field that combines mathematics, statistics, specialized programming, advanced analytics, artificial intelligence (AI), and machine learning. Its purpose is to uncover actionable insights hidden within an organization’s data. These insights guide decision-making and strategic planning. The significance of data science spans across industries, a few examples are:
#
# **Business**: Data science optimizes operations, predicts consumer behavior, and drives growth.
#
# **Healthcare**: Personalized medicine, predictive analytics, and disease prevention benefit from data science.
#
# **Finance**: Risk assessment, fraud detection, and customer analysis rely on data-driven decisions.
#
# **National Security**: Data scientists ensure reliable, consistent, and secure information for critical business choices.

# %% [markdown]
# Setting up the Environment: Install necessary Python libraries for data science (e.g., NumPy, Pandas, Matplotlib) using Jupyter Notebook cells.

# %%
# import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization

# %% [markdown]
# Loading and Displaying Data:
# *   Import a dataset of your choice (e.g., CSV or Excel file) using Pandas.
# *  Display the first few rows of the dataset to understand its structure.

# %%
# Load the dataset into a Pandas DataFrame
unemployment = pd.read_csv(r"/content/drive/MyDrive/OASIS/Unemployment in India.csv")

#Displaying the first few rows of the dataset
unemployment.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6  Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7  Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8  Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9  Andhra Pradesh   29-02-2020    Monthly                              5.91
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %% [markdown]
# # Task 2: Core Concepts and Principles

# %% [markdown]
# Data Types and Structures:
#
# *   Create variables representing different data types(integer, float, string).
# *   Explore and demonstrate basic operations on these variables.

# %%
value = 10 #create integer
print("Type of value:", type(value))

Marks = 84.3 #create float
print("Type of Marks:", type(Marks))

Name = "Swati" #create string
print("Type of Name:", type(Name))
# Out:
# Type of value: <class 'int'>
# Type of Marks: <class 'float'>
# Type of Name: <class 'str'>

# %%
#Number operations
print("sum of value and Marks:", value+Marks) #output will be float
print("Multiplication", Marks*1.5)
print("Division", Marks/value)
print("Greater", Marks > value)
# Out:
# sum of value and Marks: 94.3
# Multiplication 126.44999999999999
# Division 8.43
# Grater True

# %%
#string operations
print(Name[:3]) #letters from index 0 to 2
print(Name[2:4]) #slicing
print(Name[-3:-1])#same as above
print(Name[::-1]) #reverse the string
print(Name*2) #print name twice
print(Name+Name) #same as above
# Out:
# Swa
# at
# at
# itawS
# SwatiSwati
# SwatiSwati

# %% [markdown]
# Data Manipulation:
#
# *   Apply data manipulation techniques using Pandas.
# *   Perform tasks such as filtering, sorting, and grouping on the loaded dataset.

# %%
#get data taypes of dataframe
unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
print(unemployment.columns) #print column names
# Strip trailing spaces from columns names
unemployment.columns =unemployment.columns.str.strip()
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# Convert 'Date' column to datetime format
unemployment['Date'] = pd.to_datetime(unemployment['Date'])

# %%
#Check duplicates
unemployment.duplicated().sum()
# Out:
# 27

# %%
#remove duplicates
unemployment.drop_duplicates(inplace = True)

# %%
#Find missing values
unemployment.isnull().sum()
# Out:
# Region                                     1
# Date                                       1
# Frequency                                  1
# Estimated Unemployment Rate (%)            1
# Estimated Employed                         1
# Estimated Labour Participation Rate (%)    1
# Area                                       1
# dtype: int64

# %%
#drop rows with null values
unemployment.dropna(inplace = True)

unemployment.info()

print(unemployment.head()) #Print first 5 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 46.2+ KB
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# ...

# %%
#Drop frequency column as it is monthly only
unemployment.drop(["Frequency"], axis=1, inplace=True)

# %%
# apply filtering on the loaded dataset.
#Find dates and regions when unemployment rate is >50%
high_unemp = unemployment[unemployment["Estimated Unemployment Rate (%)"] > 50]
print(high_unemp)
# Most taffected COVID regions are Jharkhand, Puducherry, Tamil Nadu and Bihar in the months of April and May 2020.
# Out:
#          Region       Date  Estimated Unemployment Rate (%)  \
# 145   Jharkhand 2020-05-31                            55.10
# 242  Puducherry 2020-04-30                            74.51
# 287  Tamil Nadu 2020-04-30                            53.19
# 412       Bihar 2020-04-30                            58.77
# 530   Jharkhand 2020-04-30                            61.48
# 531   Jharkhand 2020-05-31                            70.17
# 627  Puducherry 2020-04-30                            76.74
# 628  Puducherry 2020-05-31                            75.00
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 145           3315038.0                                    37.03  Rural
# 242             49420.0                                    46.79  Rural
# 287           5086200.0                                    33.05  Rural
# 412           1400962.0                                    34.94  Urban
# ...

# %%
#Least affected regions during these peak covid time
# Filter by dates in the specified range and sort by 'Estimated Unemployment Rate (%)'
filtered_data = unemployment[(unemployment['Date'] >= '2020-04-01') & (unemployment['Date'] <= '2020-06-30')]
sorted_data = filtered_data.sort_values(by='Estimated Unemployment Rate (%)')

# Display the sorted data
print(sorted_data.head(5)) #least affected regions are Sikkim, Chattisgarh, Assam, Andhra Pradesh and Himachal Pradesh, all are rural areas
# Out:
#                Region       Date  Estimated Unemployment Rate (%)  \
# 274            Sikkim 2020-04-30                             0.00
# 51       Chhattisgarh 2020-04-30                             0.00
# 25              Assam 2020-06-30                             0.00
# 13     Andhra Pradesh 2020-06-30                             0.85
# 121  Himachal Pradesh 2020-06-30                             1.12
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 274            133399.0                                    37.72  Rural
# 51            6534321.0                                    39.43  Rural
# 25            7544937.0                                    34.38  Rural
# 13           15572975.0                                    53.76  Rural
# 121           2230075.0                                    41.20  Rural

# %%
# Group by a specific region, sum the values, and then sort the data
sorted_data_region = unemployment.groupby('Region')['Estimated Unemployment Rate (%)'].sum().reset_index(name='Total Unemployment Rate').sort_values(by='Total Unemployment Rate', ascending=False)
print(sorted_data_region)
# Out:
#               Region  Total Unemployment Rate
# 24           Tripura                   793.81
# 8            Haryana                   735.93
# 11         Jharkhand                   576.38
# 2              Bihar                   529.71
# 9   Himachal Pradesh                   519.13
# 5              Delhi                   461.87
# 20         Rajasthan                   393.63
# 25     Uttar Pradesh                   351.44
# 10   Jammu & Kashmir                   339.96
# 19            Punjab                   336.87
# 13            Kerala                   283.47
# 18        Puducherry                   265.59
# 22        Tamil Nadu                   259.96
# 4       Chhattisgarh                   258.73
# 27       West Bengal                   227.49
# 6                Goa                   222.58
# 23         Telangana                   216.66
# 15       Maharashtra                   211.61
# 0     Andhra Pradesh                   209.36
# ...

# %% [markdown]
# Feature Engineering:
# *   Create a new feature based on existing features in the dataset.
# *   Explain the rationale behind the feature engineering process.

# %%
# Create a new feature 'Labor force'
unemployment['Labor Force'] = unemployment['Estimated Employed'] / (unemployment['Estimated Labour Participation Rate (%)'] / 100)
unemployment.head()
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#     Labor Force
# 0  2.775009e+07
# 1  2.795691e+07
# 2  2.778553e+07
# 3  2.794108e+07
# 4  2.743232e+07

# %% [markdown]
# *   Changed the data type of date column to datetime for further analyzing the data
# *   Removed duplicates as they hold no meaning and don't contribute anything new to dataset.
# *   Removed rows with missing values as they may affect the future analysis process and model building.
# *   Removed "Frequency" column as this has same value for all the rows.
# *   The labor force calculation provides an estimate of the total number of individuals who are either contributing to the workforce through employment or are actively looking for employment. A high labor force participation rate indicates a large portion of the population is actively engaged in the workforce.

# %% [markdown]
# # Task 3: Statistical Analysis

# %% [markdown]
# Descriptive Statistics: Compute and interpret key descriptive statistics (mean, median, standard deviation) for relevant columns in the dataset.

# %%
unemployment.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)   Labor Force
# count                               740.000000  7.400000e+02
# mean                                 42.630122  1.722295e+07
# std                                   8.111094  1.959643e+07
# min                                  13.330000  1.056209e+05
# 25%                                  38.062500  2.773079e+06
# 50%                                  41.160000  1.243555e+07
# ...

# %% [markdown]
# *   The mean unemployment rate is 11.78 and median is 8.35, positively skewed distribution, there are some extreme values on right side of distrubtion leading to conclusion that there are some regions having very high unemployment rates.
# *   The standard devation value is very large for unemployment rate as well as estimated employed, suggesting large spread in data distribution.
# *   The Estimated Labour Participation Rate (%) has mean ~ median which points to near normal distribution.

# %% [markdown]
# Inferential Statistics:
#
# *   Formulate a hypothesis related to the dataset.
# *   Conduct a statistical test (e.g., t-test) to test the hypothesis.
# *   Provide conclusions based on the test results.

# %% [markdown]
# Analysis of variance (ANOVA) to assess whether there are statistically significant differences in the mean unemployment rates across different regions.
#
# Null Hypothesis(H0): There is no significant difference in the mean unemployment rates across different regions.
#
# Alternative Hypothesis(H1): There is a significant difference in the mean unemployment rates across at least two regions.

# %%
from scipy.stats import f_oneway

# Apply ANOVA
result = f_oneway(*[group['Estimated Unemployment Rate (%)'] for name, group in unemployment.groupby('Region')])

print("ANOVA Results:")
print("F-statistic:", result.statistic)
print("P-value:", result.pvalue)
# Out:
# ANOVA Results:
# F-statistic: 13.34553688739108
# P-value: 3.616584140292138e-47

# %% [markdown]
# Conclusion: With such a low p-value, we have strong evidence to reject the null hypothesis. This suggests that there are statistically significant differences in the mean unemployment rates across different regions.
#
# F-Statistic: The F-statistic is a ratio of the variance between groups to the variance within groups. In our case, it is 13.35. A higher F-statistic suggests that there is more variability between groups relative to within groups.

# %% [markdown]
# # Task 4: Exploratory Data Analysis

# %% [markdown]
# Data Visualization:
#
#
# *   Create at least three visualizations (e.g., histograms, scatter plots, boxplots) to explore relationships within the dataset.
# *   Include appropriate labels and titles for clarity.

# %%
#separate out numerical columns
numeric_columns = unemployment.select_dtypes(include = "number").columns
print(numeric_columns)
# Out:
# Index(['Estimated Unemployment Rate (%)', 'Estimated Employed',
#        'Estimated Labour Participation Rate (%)', 'Labor Force'],
#       dtype='object')

# %%
# Create a histogram for the features
unemployment[numeric_columns].hist(bins=20, figsize=(12, 8))
plt.show()
#Unemployment rate, estimated employed and labor force all are right skewed distribution having outliers/extreme values on right side of distribution

# %%
#density plot
unemployment[numeric_columns].plot(kind ='density',subplots = True, layout =(2,2),sharex = False, figsize = (12,8))
plt.show()

# %%
unemployment[numeric_columns].plot(kind ='box', subplots = True, layout =(2,2), sharex = False, sharey = False, figsize=(12, 8))
plt.show()
#all the four features have outliers

# %%
#scatter plots/coorelation plots

#Define custome pallete
custom_palette = sns.color_palette("husl", 2)
# Rename columns
column_rename_mapping = {
    'Estimated Unemployment Rate (%)': 'Unemployment Rate',
    'Estimated Employed': 'Employed',
    'Estimated Labour Participation Rate (%)': 'Labour Participation Rate',
    'Labor Force': 'Labor Force'
}
unemployment_renamed = unemployment.rename(columns=column_rename_mapping)

# Create pairplot with custom palette and increased figure size
plot = sns.pairplot(unemployment_renamed, hue='Area', palette=custom_palette)

plt.show()
#Labor force and estimated emoplyment has strong positive relationship which is understood as labor force was derived from this column.
#Unemployment rate is little bit high in rural areas than urban areas

# %% [markdown]
# Outlier Detection:
#
# *   Identify and handle outliers in the dataset.
# *   Explain the methodology and reasoning behind your approach.

# %%
# Define the outlier criteria
# using the IQR method to identify outliers
def outlier(dataset, column):
    Q1 = dataset[column].quantile(0.25)
    Q3 = dataset[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    outliers = dataset[(dataset[column] < lower_limit) | (dataset[column] > upper_limit)]
    return outliers[column].count()

for i in numeric_columns:
  outlier_count = outlier(unemployment, i)
  print(f"Number of outliers in {i}: {outlier_count}")
# Out:
# Number of outliers in Estimated Unemployment Rate (%): 35
# Number of outliers in Estimated Employed: 15
# Number of outliers in Estimated Labour Participation Rate (%): 63
# Number of outliers in Labor Force: 25

# %%
#Use winsorization to handle outliers
from feature_engine.outliers import Winsorizer

# Fit and transform the specified columns
for column in numeric_columns:
    winsorizer = Winsorizer(capping_method='iqr', tail='both', fold=1.5, variables=[column])
    unemployment[column] = winsorizer.fit_transform(unemployment[[column]])

unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Estimated Unemployment Rate (%)          740 non-null    float64
#  3   Estimated Employed                       740 non-null    float64
#  4   Estimated Labour Participation Rate (%)  740 non-null    float64
#  5   Area                                     740 non-null    object
#  6   Labor Force                              740 non-null    float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 46.2+ KB

# %%
#Boxplot to verify if outliers are removed
unemployment[numeric_columns].plot(kind ='box', subplots = True, layout =(2,2), sharex = False, sharey = False, figsize=(12, 8))
plt.show()
#no outliers

# %% [markdown]
# The Winsorizer object is used to fit and transform the specified features in the DataFrame. It replaces values beyond the specified thresholds (IQR ± 1.5) with the nearest values within those thresholds, effectively mitigating the impact of extreme values on the distribution of the data.

# %% [markdown]
# Correlation Analysis: Compute and interpret the correlation between two relevant variables in the dataset.

# %%
# Correlation matrix
correlation_matrix = unemployment.corr()

# heatmap of the correlations
plt.figure(figsize = (8, 6))
sns.heatmap(correlation_matrix, annot = True, cmap = "coolwarm", fmt= '.2f')
plt.title("Correlation Matrix")
plt.show()
# Out:
# <ipython-input-33-c999f058ea71>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = unemployment.corr()

# %% [markdown]
# *   Labor force is derived from estimated employed feature, so they have strong positve coorelation 0.98, we can remove the derive column "labor force" as this may impact further analysis.
# *   There are no significant coorelations b/w other columns

# %%
unemployment.drop(["Labor Force"], axis=1, inplace = True)
unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 6 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Estimated Unemployment Rate (%)          740 non-null    float64
#  3   Estimated Employed                       740 non-null    float64
#  4   Estimated Labour Participation Rate (%)  740 non-null    float64
#  5   Area                                     740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 40.5+ KB

# %%
#we install dython libraray to check coorelations b/w all the columns, numerical as well as categorical
# !pip install dython

# %%
from dython.nominal import associations

# Calculate associations between categorical variables
correlation_matrix, _ = associations(unemployment)

# Display the correlation matrix
print(correlation_matrix)
# Out:
# corr

# %% [markdown]
# *   Strong positive coorelation b/w region and Estimated Employed
# *   Region has moderate positive coorelations with Estimated Unemployment rate and Estimated Labor Participation rate.
